# %% [markdown]
# ### Trabalho de Estatistica - Correlação

# %% [markdown]
# #### Definição:
# A correlação que o pandas implementa por padrão é a correlação de Pearson.
#
# Este coeficiente assume valores entre -1 e 1, onde um valor 1 significa uma correlação positiva perfeita entre as variáveis e um valor -1 uma correlação negativa perfeita entre as variáveis.
#
# Os valores 0 significa que não há uma correlação entre as variáveis.

# %% [markdown]
# ### 1. Usando sua **intuição**, classifique os seguintes pares (x, y) como tendo uma correlação fraca (0 < r < 0,5), uma correlação moderada ( 0,5 < r < 0,8) ou uma correlação forte (0,8 < r < 1,0).
#
#  - (a) (peso, pescoço)
#  - (b) (peso, altura)
#  - (c) (idade, gordura corporal)
#  - (d) (peito, quadril)
#  - (e) (idade, pulso)
#  - (f) (tornozelo, pulso)
#  - (g) (antebraço, altura)
#  - (h) (bíceps, antebraço)
#  - (i) (peso, gordura do corpo)
#  - (j) (joelho, coxa)
#  - (k) (quadril, abdome)
#  - (l) (abdome, quadril)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame()

# %%
Colunas = [
    'Idade(anos)',
    'Peso(libras)',
    'Altura(pol)',
    'Pescoco(cm)',
    'Peito(cm)',
    'Abdome(cm)',
    'Quadril(cm)',
    'Coxa(cm)',
    'Joelho(cm)',
    'Tornozelo(cm)',
    'Biceps(cm)',
    'Antebraco(cm)',
    'Pulso(cm)',
    'Gordura corporal(%)',
]

dados = [
    [22 ,173.25 ,72.25 ,38.5 ,93.6 ,83.0, 98.7, 58.7, 37.3, 23.4 ,30.5, 28.9, 18.2, 6.1],
    [22, 154.00, 66.25, 34.0, 95.8, 87.9, 99.2, 59.6, 38.9, 24.0, 28.8, 25.2, 16.6, 25.3],
    [23, 154.25, 67.75, 36.2, 93.1, 85.2, 94.5, 59.0, 37.3, 21.9, 32.0, 27.4, 17.1,12.3],
    [23, 198.25, 73.50, 42.1, 99.6, 88.6, 104.1, 63.1, 41.7, 25.0, 35.6, 30.0, 19.2,11.7],
    [23, 159.75, 72.25, 35.5, 92.1, 77.1, 93.9, 56.1, 36.1, 22.7, 30.5, 27.2, 18.2, 9.4],
    [23, 188.15, 77.50, 38.0, 96.6, 85.3, 102.5, 59.1, 37.6, 23.2, 31.8, 29.7, 18.3, 10.3],
    [24, 184.25, 71.25, 34.4, 97.3, 100.0, 101.9, 63.2, 42.2, 24.0, 32.2, 27.7, 17.7, 28.7],
    [24, 210.25, 74.75, 39.0, 104.5, 94.4, 107.8, 66.0, 42.0, 25.6, 35.7, 30.6, 18.8, 20.9],
    [24, 156.00, 70.75, 35.7, 92.7, 81.9, 95.3, 56.4, 36.5, 22.0, 33.5, 28.3, 17.3, 14.2]
]


df = pd.DataFrame(dados, columns=Colunas)
df
# Out:
#    Idade(anos)  Peso(libras)  Altura(pol)  Pescoco(cm)  Peito(cm)  Abdome(cm)  \
# 0           22        173.25        72.25         38.5       93.6        83.0
# 1           22        154.00        66.25         34.0       95.8        87.9
# 2           23        154.25        67.75         36.2       93.1        85.2
# 3           23        198.25        73.50         42.1       99.6        88.6
# 4           23        159.75        72.25         35.5       92.1        77.1
# 5           23        188.15        77.50         38.0       96.6        85.3
# 6           24        184.25        71.25         34.4       97.3       100.0
# 7           24        210.25        74.75         39.0      104.5        94.4
# 8           24        156.00        70.75         35.7       92.7        81.9
#
#    Quadril(cm)  Coxa(cm)  Joelho(cm)  Tornozelo(cm)  Biceps(cm)  \
# 0         98.7      58.7        37.3           23.4        30.5
# ...

# %%
# plot do pandas
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_9022e_row0_col0,#T_9022e_row1_col1,#T_9022e_row2_col2,#T_9022e_row3_col3,#T_9022e_row4_col4,#T_9022e_row5_col5,#T_9022e_row6_col6,#T_9022e_row7_col7,#T_9022e_row8_col8,#T_9022e_row9_col9,#T_9022e_row10_col10,#T_9022e_row11_col11,#T_9022e_row12_col12,#T_9022e_row13_col13{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_9022e_row0_col1{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_9022e_row0_col2,#T_9022e_row2_col10{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_9022e_row0_col3{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }#T_9022e_row0_col4,#T_9022e_row0_col6,#T_9022e_row0_col9,#T_9022e_row2_col7,#T_9022e_row2_col8,#T_9022e_row3_col0,#T_9022e_row3_col5,#T_9022e_row3_col13,#T_9022e_row13_col1,#T_9022e_row13_col2,#T_9022e_row13_col3,#T_9022e_row13_col10,#T_9022e_row13_col11,#T_9022e_row13_col12{
# ...

# %%
# plot seaborn
import seaborn as sns
corr = df.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
#  ### 2. Agora, use tecnologia para encontrar o coeficiente de correlação para cada par no Exercício 1. Compare seus resultados com aqueles obtidos por intuição.
#
#  #### correlação fraca (0 < r < 0,5)
#  #### correlação moderada ( 0,5 < r < 0,8)
#  #### correlação forte (0,8 < r < 1,0).
#
#  - (a) (peso, pescoço)             **-0.027460 correlação fraca**
#  - (b) (peso, altura)              **0.745801 correlação moderada**
#  - (c) (idade, gordura corporal)  **0.350837 correlação fraca**
#  - (d) (peito, quadril)            **0.952995 correlação forte**
#  - (e) (idade, pulso)              **0.204591 correlação fraca**
#  - (f) (tornozelo, pulso)          **0.579548 correlação moderada**
#  - (g) (antebraço, altura)         **0.843946 correlação forte**
#  - (h) (bíceps, antebraço)         **0.798380 correlação moderadda**
#  - (i) (peso, gordura do corpo)   **0.116324	 correlação fraca**
#  - (j) (joelho, coxa)              **0.954305	correlação forte**
#  - (k) (quadril, abdome)           **0.710352 correlação moderada**
#  - (l) (abdome, quadril)           **1.000000 correlação forte**

# %% [markdown]
# ### 3. Use tecnologia para encontrar a reta de regressão para cada par no Exercício 1 que tenha uma correlação forte.

# %% [markdown]
# #### Regressão (peito, quadril)            **0.952995 correlação forte**

# %%
from sklearn.linear_model import LinearRegression
X = df.iloc[:, 4].values.reshape(-1, 1)  # df.iloc[:, 4] é a coluna do df['Peito(cm)'] X
Y = df.iloc[:, 6].values.reshape(-1, 1)  # df.iloc[:, 6] é a coluna do df['Quadril(cm)'] Y
linear_regressor = LinearRegression()
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)
X
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %% [markdown]
# #### Regressão (antebraço, altura)         **0.843946 correlação forte**

# %%
from sklearn.linear_model import LinearRegression
X = df.iloc[:, 11].values.reshape(-1, 1)  # df.iloc[:, 11] é a coluna do df['Antebraco(cm)'] X
Y = df.iloc[:, 2].values.reshape(-1, 1)  # df.iloc[:, 2] é a coluna do df['Altura(pol)'] Y
linear_regressor = LinearRegression()
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)
X
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %% [markdown]
# #### Regressão (joelho, coxa)  **0.954305	correlação forte**

# %%
from sklearn.linear_model import LinearRegression
X = df.iloc[:, 8].values.reshape(-1, 1)  # df.iloc[:, 11] é a coluna do df['Joelho(cm)'] X
Y = df.iloc[:, 7].values.reshape(-1, 1)  # df.iloc[:, 2] é a coluna do df['Coxa(cm)'] Y
linear_regressor = LinearRegression()
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)
X
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %% [markdown]
#  #### Regressão (abdome, quadril)           **1.000000 correlação forte**

# %%
from sklearn.linear_model import LinearRegression
X = df.iloc[:, 5].values.reshape(-1, 1)  # df.iloc[:, 11] é a coluna do df['Abdome(cm)'] X
Y = df.iloc[:, 6].values.reshape(-1, 1)  # df.iloc[:, 2] é a coluna do df['Quadril(cm)'] Y
linear_regressor = LinearRegression()
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)
X
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %% [markdown]
# 4. Use os resultados do Exercício 3 para prever o seguinte:
# - (a) A circunferência do quadril de um homem cuja circunferência do peito é 95 cm.
# - (b) A altura de um homem cuja circunferência do antebraço é 28 cm.

# %% [markdown]
# 5. Há pares de variáveis que tenham coeficientes de correlação mais fortes que 0,85?
# Use tecnologia e intuição para chegar a uma conclusão.
